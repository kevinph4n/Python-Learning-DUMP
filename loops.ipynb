# %% [markdown]
# #### range(N)

# %%
range(3)
# Out:
# range(0, 3)

# %% [markdown]
# #### For loops
# - Loops: perform a task over and over

# %%
squares = ['red', 'yellow', 'green', 'purple', 'blue']

for i in range(0,5):
    squares[i]='whie'

# %%
squares = ['red', 'yellow', 'green']

for i, square in enumerate(squares):
    square
    i

# %%
for x in ['A', 'B', 'C']:
    print(x+'A')

# The list is ['A', 'B', 'C']
# for function will concatenate each of them with:
# 1st: x = 'A'
# 2nd: x = 'B'
# ... -> 'A' + 'A' = 'AA' and so on
# Out:
# AA
# BA
# CA

# %%
for i, x in enumerate(['A', 'B', 'C']):
    print(i,x)

# with enumerate, it's just like [(0, 'A'), (1, 'B'), (2, 'C')] (just e.g)
# 1st: i = 0; x = 'A' -> print(i, x) = 0 A
# ... and so on
# Out:
# 0 A
# 1 B
# 2 C

# %% [markdown]
# #### While loops
# - While loops: will only run if a condition is met

# %%
squares = ['red', 'red', 'blue', 'red', 'green']
new_squares=[]
i = 0 # the index starts at 0

while(squares[i]=='red'): # this statement will repeatedly execute the statements
    # until the condition inside the bracket is False
    new_squares.append(squares[i]) 
    # append from the list 'squares' to the list "news_quares"
    i = i + 1

# %% [markdown]
# ![image.png](attachment:image.png)
