# %% [markdown]
# - Pandas is a popular library for data analyst
# using this by
# import pandas

# %%
import pandas as cuteanimals # u can call it whatever u want
# you can now have access to pre-built classes and functions such as:
# read_csv()
# Series()
# DataFrame
# Values
csv_path = 'file1.csv'
df = cuteanimals.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as cuteanimals # u can call it whatever u want
#       2 # you can now have access to pre-built classes and functions such as:
#       3 # read_csv()
#       4 # Series()
#
# ModuleNotFoundError: No module named 'pandas'
