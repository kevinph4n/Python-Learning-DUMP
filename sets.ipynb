# %% [markdown]
# ### Sets
# - unlike lists and tuples, sets are unordered (do not record element position)

# %%
Set1 = {'ballad', 'bop', 'rock', 'bop', 'RnB', 'disco'}
print(Set1)
# -> duplicate items will not be present in Sets
# Out:
# {'RnB', 'rock', 'disco', 'bop', 'ballad'}

# %% [markdown]
# #### 1/ .set()

# %%
list1 = ['kevinph4n', 'is', 'handsome', 'handsome', 2008]
list1_set = set(list1)
print(list1_set)
# Out:
# {'is', 'kevinph4n', 'handsome', 2008}

# %% [markdown]
# #### 2/ .add()

# %%
A = {"thriller", "ballad", "rnb"}
A.add("kevin")
print(A)
# Out:
# {'rnb', 'kevin', 'thriller', 'ballad'}

# %%
A = {"thriller", "ballad", "rnb"}
A.add("kevin")
"kevin" in A
# Out:
# True

# %% [markdown]
# #### 3/ Sets Mathematical Set Operations

# %%
# &
album_set1 = {"AC/DC", "Back in Black", "Thriller"}
album_set2 = {"AC/DC", "Back in Black", "The Dark Side of the Moon"}
album_set_similar = album_set1 & album_set2
print(album_set_similar)
# Out:
# {'Back in Black', 'AC/DC'}

# %%
# .union()
album_set1 = {"AC/DC", "Back in Black", "Thriller"}
album_set2 = {"AC/DC", "Back in Black", "The Dark Side of the Moon"}
album_set_union = album_set1.union(album_set2)
print(album_set_union)
# Out:
# {'Thriller', 'The Dark Side of the Moon', 'Back in Black', 'AC/DC'}

# %%
# .issubset()
album_set1 = {"AC/DC", "Back in Black", "Thriller"}
album_set2 = {"AC/DC", "Back in Black", "Thriller", "The Dark Side of the Moon"}
album_set1.issubset(album_set2)
# Out:
# True
